# %% [markdown]
# # Lancaster Housing Association Lettings

# %% [markdown]
# The code below downloads the data found in the historic lettings section of the Ideal Choice Homes [website](https://www.idealchoicehomes.co.uk/Data/ASPPages/1/56.aspx) which is a published list of properties that have been let in a given week.  This notebook goes through the steps of automatically downloading and collating the data.  If ran at another time the data downloaded may be different, I don't know if the published data is a rolling window or not.
#
# It should be noted that the properties that are let may not be indicative of all the properties that were available to rent, as they may not have been let and so recorded.  If this is a situation that's possible the data will not give a complete picture of the number and type of lettings that have been made available historically, and at what times of the year.

# %% [markdown]
# ## Library Imports

# %% [markdown]
# Below we import pre-existing code libraries, called modules.  Each module can provide pre-made classes and/or functions that make it easier to carry out the task by re-using existing code.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import datefinder

# %% [markdown]
# ## Web Data Scraping

# %% [markdown]
# In this section, code will connect to the website and after a process of link-harvesting, will download all the letting information.  There are five stages to this:
#
# 1. Connect to the first page of links to lettings, verify that this connection was successful.
# 2. Using the page above, identify all the paginated links, e.g. page 2, page 3, page 4 of the links to lettings.
# 3. Iterate through each of the pages identified in stage 2, and add each link found with the letting cycle prefix to a list.
# 4. For each of the URI's in the list produced by stage 3, go to each page and look for housing data, harvesting and appending to a data frame if found.
# 5. Write the harvested data to a CSV formatted file.

# %% [markdown]
# ## Web Data Scraping: stage 1
#
# In the code block below the webpage is accessed, and a print command outputs a sentence that is finished with the outcome of the request.  This check of the request's outcome is performed here for example, but at all later points it is assumed that a connection is OK.
#
# The variable `root_address` is created, this is the base URI of the website that all the links we will programatically access are in relation to; it will be used as a prefix.

# %%
# Use the base links_page to point to the first of the lettings cycle list pages
links_page = requests.get("https://www.idealchoicehomes.co.uk/Data/ASPPages/1/56.aspx")

# Base site address to use with the harvested links
root_address = 'https://www.idealchoicehomes.co.uk'

# Check that the request was successful 
print("The request was {}".format('successful' if links_page.status_code == 200 else 'unsuccessful'))
# Out:
# The request was successful

# %% [markdown]
# ## Web Data Scraping: stage 2
#
# Find all the `a` link tags in the page, then filter further by checking for a `href` attribute, and where present does it contain the prefix that all the paginated links contain.  All these links are added to a single list.

# %%
# Create the BS4 object from the retrieved page from the block above
soup = BeautifulSoup(links_page.content, 'html.parser')

# When looking for links, we are looking for 'a' tags that have the href_prefix below.
href_prefix = '/Data/ASPPages/1/56.aspx?CurrentPage='

# Retrieve all the 'a' elements within the page
links = soup.find_all('a')

# Filter all the 'a' elements to find those with the href attribute and the prefix within the href attribute
pages_with_links = [matching_link['href'] for matching_link in links 
                      if 'href' in matching_link.attrs and href_prefix in matching_link['href']]

# Add the first page manually, as it doesn't have an 'a' tag when it is the already selected page
pages_with_links.append('/Data/ASPPages/1/56.aspx?CurrentPage=1')

# Remove duplicates, for some reason page 2 is duplicated, unsure why, fast way to remove
pages_with_links = list(set(pages_with_links))

# %% [markdown]
# ## Web Data Scraping: stage 3
#
# In the block below, each of the web pages in the `pages_with_link` list is visited, and the links on each page that have the letting cycle infix `LettingCycleID` is collated into a list.

# %%
# For every page in the page_with_links list, we will find the lettingcycle links, as each of these pages should 
#   have letting data.

# The signature we're looking for in the href attribute of 'a' tags to indicate a lettings cycle page link
letting_infix = "LettingCycleID="

# The list that will hold the letting cycle links
letting_cycle_links = []

# Iterate through all the paginated pages, and add the multiple links per page to letting information
for current_link in pages_with_links:
    # Retrieve the page, parse, and search the 'a' tags for the letting_infix, we assume each page will resolve OK
    #  there is no validation of this.
    numbered_page = requests.get(root_address + current_link)
    soup = BeautifulSoup(numbered_page.content, 'html.parser')
    letting_cycle_links = ([matching_link['href'] for matching_link in soup.find_all('a')
                           if 'href' in matching_link.attrs and letting_infix in matching_link['href']] +
                           letting_cycle_links)

# %% [markdown]
# ## Web Data Scraping: stage 4
#
#
# In the block below we create an empty data frame with columns headings, then populate it by iterating through the letting cycle links, finding the table rows that contain data, and appending them to the data frame.  There are multiple tables on the target pages, and so we are looking for those that have `nine` `td` elements - this assumes that all pages have the same table structure, and that it hasn't changed over time.  It's crude, maybe change to look for table elements instead, and harvest data where the columns have matching headers.

# %%
# The column headers for the data frame
df_columns = ['area',
              'band',
              'date',
              'bids',
              'type',
              'floor',
              'bedrooms',
              'sheltered',
              'ref',
              'cycle_start',
              'cycle_end']

# The creating of the housing data frame
housing_df = pd.DataFrame(columns=df_columns)

# For every letting cycle link, follow and harvest the data
for current_letting_cycle in letting_cycle_links:
    
    # Print out the page that's currently being accessed to provide some feedback to the user about what is
    #  currently happening.
    print("On page: {}".format(current_letting_cycle))
    
    # Access the letting cycle data page given by the current letting cycle link, and create the BeautifulSoup
    #   object.
    data_page = requests.get(root_address + current_letting_cycle)
    soup = BeautifulSoup(data_page.content, 'html.parser')

    # Find the letting cycle dates by checking all paragraphs until the matching one is found, then extract dates
    #  to apply to all elements in the pages table
    paragraphs = soup.find_all('p')
    for current_paragraph in paragraphs:
        if 'The results for properties advertised' in current_paragraph.text:
            # Use the source rather than converted date, it tends to mix d/m/y m/d/y formats
            dates = list(datefinder.find_dates(current_paragraph.text, source=True))
            if len(dates) == 2:
                cycle_start = str(dates[0][1])
                cycle_end = str(dates[1][1])
    
                # Find all the table rows, 'tr' elements, and with them iterate through their 'td' elements.  Some pages 
                #  don't have tables for whatever reason, and so it is necessary to check that tr elements exist, and that
                #  td elements exist within them.
                table_rows = soup.find_all('tr')

                if len(table_rows) > 0:

                    # Iterate through all the table rows, and check that the one being looked at has nine elements as this 
                    #   matches the structure of the data tables (todo: change to find tables, and check the headers rather than
                    #   element size).
                    for current_row in table_rows:

                        row_columns = current_row.find_all('td')

                        if len(row_columns) == 9:
                            # We expect each table to have exactly the same columns as each other, and so can access them
                            #  using their position.
                            row_area = row_columns[0].string
                            row_band = row_columns[1].string
                            row_date = row_columns[2].string
                            row_bids = row_columns[3].string
                            row_type = row_columns[4].string
                            row_floor = row_columns[5].string
                            row_bedrooms = row_columns[6].string
                            row_sheltered = row_columns[7].string
                            row_ref = row_columns[8].string
                            housing_df = housing_df.append({
                                'area': row_area,
                                'band': row_band,
                                'date': row_date,
                                'bids': row_bids,
                                'type': row_type,
                                'floor': row_floor,
                                'bedrooms': row_bedrooms,
                                'sheltered': row_sheltered,
                                'ref': row_ref,
                                'cycle_start': cycle_start,
                                'cycle_end': cycle_end
                            }, ignore_index=True)
# Out:
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=28&LettingCycleID=630191
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=28&LettingCycleID=630190
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=28&LettingCycleID=630189
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=28&LettingCycleID=630188
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=28&LettingCycleID=630187
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=28&LettingCycleID=630186
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=28&LettingCycleID=630185
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=28&LettingCycleID=630184
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=28&LettingCycleID=630183
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=28&LettingCycleID=630182
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=27&LettingCycleID=630203
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=27&LettingCycleID=630202
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=27&LettingCycleID=630201
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=27&LettingCycleID=630200
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=27&LettingCycleID=630199
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=27&LettingCycleID=630198
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=27&LettingCycleID=630197
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=27&LettingCycleID=630196
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=27&LettingCycleID=630193
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=27&LettingCycleID=630192
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=22&LettingCycleID=630253
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=22&LettingCycleID=630252
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=22&LettingCycleID=630251
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=22&LettingCycleID=630250
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=22&LettingCycleID=630249
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=22&LettingCycleID=630248
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=22&LettingCycleID=630247
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=22&LettingCycleID=630246
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=22&LettingCycleID=630245
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=22&LettingCycleID=630244
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=2&LettingCycleID=630455
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=2&LettingCycleID=630454
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=2&LettingCycleID=630453
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=2&LettingCycleID=630452
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=2&LettingCycleID=630451
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=2&LettingCycleID=630450
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=2&LettingCycleID=630449
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=2&LettingCycleID=630448
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=2&LettingCycleID=630447
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=2&LettingCycleID=630446
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=31&LettingCycleID=630159
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=31&LettingCycleID=630158
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=31&LettingCycleID=630157
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=31&LettingCycleID=630156
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=31&LettingCycleID=630155
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=31&LettingCycleID=630154
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=31&LettingCycleID=630153
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=31&LettingCycleID=630152
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=31&LettingCycleID=630151
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=31&LettingCycleID=630150
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=33&LettingCycleID=630139
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=33&LettingCycleID=630138
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=33&LettingCycleID=630137
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=33&LettingCycleID=630136
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=33&LettingCycleID=630135
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=33&LettingCycleID=630134
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=33&LettingCycleID=630133
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=33&LettingCycleID=630132
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=33&LettingCycleID=630131
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=33&LettingCycleID=630130
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=32&LettingCycleID=630149
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=32&LettingCycleID=630148
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=32&LettingCycleID=630147
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=32&LettingCycleID=630146
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=32&LettingCycleID=630145
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=32&LettingCycleID=630144
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=32&LettingCycleID=630143
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=32&LettingCycleID=630142
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=32&LettingCycleID=630141
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=32&LettingCycleID=630140
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=1&LettingCycleID=630465
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=1&LettingCycleID=630464
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=1&LettingCycleID=630463
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=1&LettingCycleID=630462
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=1&LettingCycleID=630461
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=1&LettingCycleID=630460
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=1&LettingCycleID=630459
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=1&LettingCycleID=630458
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=1&LettingCycleID=630457
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=1&LettingCycleID=630456
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=4&LettingCycleID=630435
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=4&LettingCycleID=630434
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=4&LettingCycleID=630433
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=4&LettingCycleID=630432
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=4&LettingCycleID=630431
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=4&LettingCycleID=630430
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=4&LettingCycleID=630429
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=4&LettingCycleID=630428
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=4&LettingCycleID=630427
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=4&LettingCycleID=630426
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=17&LettingCycleID=630303
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=17&LettingCycleID=630302
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=17&LettingCycleID=630301
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=17&LettingCycleID=630300
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=17&LettingCycleID=630299
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=17&LettingCycleID=630298
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=17&LettingCycleID=630297
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=17&LettingCycleID=630296
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=17&LettingCycleID=630295
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=17&LettingCycleID=630294
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=8&LettingCycleID=630395
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=8&LettingCycleID=630394
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=8&LettingCycleID=630393
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=8&LettingCycleID=630392
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=8&LettingCycleID=630391
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=8&LettingCycleID=630390
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=8&LettingCycleID=630389
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=8&LettingCycleID=630388
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=8&LettingCycleID=630387
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=8&LettingCycleID=630386
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=30&LettingCycleID=630169
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=30&LettingCycleID=630168
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=30&LettingCycleID=630167
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=30&LettingCycleID=630166
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=30&LettingCycleID=630165
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=30&LettingCycleID=630164
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=30&LettingCycleID=630163
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=30&LettingCycleID=630162
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=30&LettingCycleID=630161
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=30&LettingCycleID=630160
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=34&LettingCycleID=630129
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=34&LettingCycleID=630128
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=34&LettingCycleID=630127
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=34&LettingCycleID=630126
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=34&LettingCycleID=630125
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=34&LettingCycleID=630124
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=34&LettingCycleID=630123
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=34&LettingCycleID=630122
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=34&LettingCycleID=630121
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=34&LettingCycleID=630120
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=36&LettingCycleID=630109
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=36&LettingCycleID=630108
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=36&LettingCycleID=630107
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=20&LettingCycleID=630273
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=20&LettingCycleID=630272
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=20&LettingCycleID=630271
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=20&LettingCycleID=630270
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=20&LettingCycleID=630269
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=20&LettingCycleID=630268
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=20&LettingCycleID=630267
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=20&LettingCycleID=630266
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=20&LettingCycleID=630265
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=20&LettingCycleID=630264
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=14&LettingCycleID=630333
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=14&LettingCycleID=630332
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=14&LettingCycleID=630331
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=14&LettingCycleID=630330
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=14&LettingCycleID=630329
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=14&LettingCycleID=630328
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=14&LettingCycleID=630327
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=14&LettingCycleID=630326
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=14&LettingCycleID=630325
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=14&LettingCycleID=630324
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=13&LettingCycleID=630345
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=13&LettingCycleID=630344
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=13&LettingCycleID=630343
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=13&LettingCycleID=630340
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=13&LettingCycleID=630339
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=13&LettingCycleID=630338
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=13&LettingCycleID=630337
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=13&LettingCycleID=630336
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=13&LettingCycleID=630335
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=13&LettingCycleID=630334
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=25&LettingCycleID=630223
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=25&LettingCycleID=630222
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=25&LettingCycleID=630221
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=25&LettingCycleID=630220
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=25&LettingCycleID=630219
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=25&LettingCycleID=630218
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=25&LettingCycleID=630217
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=25&LettingCycleID=630216
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=25&LettingCycleID=630215
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=25&LettingCycleID=630214
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=12&LettingCycleID=630355
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=12&LettingCycleID=630354
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=12&LettingCycleID=630353
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=12&LettingCycleID=630352
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=12&LettingCycleID=630351
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=12&LettingCycleID=630350
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=12&LettingCycleID=630349
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=12&LettingCycleID=630348
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=12&LettingCycleID=630347
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=12&LettingCycleID=630346
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=3&LettingCycleID=630445
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=3&LettingCycleID=630444
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=3&LettingCycleID=630443
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=3&LettingCycleID=630442
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=3&LettingCycleID=630441
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=3&LettingCycleID=630440
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=3&LettingCycleID=630439
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=3&LettingCycleID=630438
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=3&LettingCycleID=630437
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=3&LettingCycleID=630436
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=15&LettingCycleID=630323
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=15&LettingCycleID=630322
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=15&LettingCycleID=630321
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=15&LettingCycleID=630320
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=15&LettingCycleID=630319
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=15&LettingCycleID=630318
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=15&LettingCycleID=630317
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=15&LettingCycleID=630316
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=15&LettingCycleID=630315
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=15&LettingCycleID=630314
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=7&LettingCycleID=630405
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=7&LettingCycleID=630404
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=7&LettingCycleID=630403
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=7&LettingCycleID=630402
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=7&LettingCycleID=630401
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=7&LettingCycleID=630400
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=7&LettingCycleID=630399
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=7&LettingCycleID=630398
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=7&LettingCycleID=630397
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=7&LettingCycleID=630396
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=11&LettingCycleID=630365
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=11&LettingCycleID=630364
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=11&LettingCycleID=630363
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=11&LettingCycleID=630362
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=11&LettingCycleID=630361
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=11&LettingCycleID=630360
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=11&LettingCycleID=630359
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=11&LettingCycleID=630358
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=11&LettingCycleID=630357
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=11&LettingCycleID=630356
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=10&LettingCycleID=630375
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=10&LettingCycleID=630374
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=10&LettingCycleID=630373
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=10&LettingCycleID=630372
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=10&LettingCycleID=630371
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=10&LettingCycleID=630370
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=10&LettingCycleID=630369
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=10&LettingCycleID=630368
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=10&LettingCycleID=630367
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=10&LettingCycleID=630366
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=23&LettingCycleID=630243
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=23&LettingCycleID=630242
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=23&LettingCycleID=630241
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=23&LettingCycleID=630240
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=23&LettingCycleID=630239
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=23&LettingCycleID=630238
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=23&LettingCycleID=630237
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=23&LettingCycleID=630236
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=23&LettingCycleID=630235
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=23&LettingCycleID=630234
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=16&LettingCycleID=630313
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=16&LettingCycleID=630312
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=16&LettingCycleID=630311
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=16&LettingCycleID=630310
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=16&LettingCycleID=630309
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=16&LettingCycleID=630308
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=16&LettingCycleID=630307
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=16&LettingCycleID=630306
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=16&LettingCycleID=630305
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=16&LettingCycleID=630304
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=6&LettingCycleID=630415
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=6&LettingCycleID=630414
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=6&LettingCycleID=630413
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=6&LettingCycleID=630412
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=6&LettingCycleID=630411
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=6&LettingCycleID=630410
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=6&LettingCycleID=630409
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=6&LettingCycleID=630408
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=6&LettingCycleID=630407
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=6&LettingCycleID=630406
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=18&LettingCycleID=630293
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=18&LettingCycleID=630292
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=18&LettingCycleID=630291
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=18&LettingCycleID=630290
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=18&LettingCycleID=630289
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=18&LettingCycleID=630288
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=18&LettingCycleID=630287
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=18&LettingCycleID=630286
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=18&LettingCycleID=630285
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=18&LettingCycleID=630284
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=19&LettingCycleID=630283
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=19&LettingCycleID=630282
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=19&LettingCycleID=630281
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=19&LettingCycleID=630280
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=19&LettingCycleID=630279
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=19&LettingCycleID=630278
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=19&LettingCycleID=630277
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=19&LettingCycleID=630276
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=19&LettingCycleID=630275
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=19&LettingCycleID=630274
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=9&LettingCycleID=630385
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=9&LettingCycleID=630384
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=9&LettingCycleID=630383
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=9&LettingCycleID=630382
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=9&LettingCycleID=630381
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=9&LettingCycleID=630380
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=9&LettingCycleID=630379
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=9&LettingCycleID=630378
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=9&LettingCycleID=630377
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=9&LettingCycleID=630376
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=26&LettingCycleID=630213
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=26&LettingCycleID=630212
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=26&LettingCycleID=630211
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=26&LettingCycleID=630210
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=26&LettingCycleID=630209
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=26&LettingCycleID=630208
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=26&LettingCycleID=630207
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=26&LettingCycleID=630206
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=26&LettingCycleID=630205
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=26&LettingCycleID=630204
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=24&LettingCycleID=630233
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=24&LettingCycleID=630232
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=24&LettingCycleID=630231
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=24&LettingCycleID=630230
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=24&LettingCycleID=630229
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=24&LettingCycleID=630228
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=24&LettingCycleID=630227
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=24&LettingCycleID=630226
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=24&LettingCycleID=630225
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=24&LettingCycleID=630224
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=21&LettingCycleID=630263
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=21&LettingCycleID=630262
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=21&LettingCycleID=630261
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=21&LettingCycleID=630260
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=21&LettingCycleID=630259
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=21&LettingCycleID=630258
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=21&LettingCycleID=630257
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=21&LettingCycleID=630256
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=21&LettingCycleID=630255
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=21&LettingCycleID=630254
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=5&LettingCycleID=630425
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=5&LettingCycleID=630424
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=5&LettingCycleID=630423
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=5&LettingCycleID=630422
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=5&LettingCycleID=630421
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=5&LettingCycleID=630420
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=5&LettingCycleID=630419
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=5&LettingCycleID=630418
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=5&LettingCycleID=630417
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=5&LettingCycleID=630416
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=29&LettingCycleID=630181
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=29&LettingCycleID=630180
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=29&LettingCycleID=630179
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=29&LettingCycleID=630178
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=29&LettingCycleID=630177
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=29&LettingCycleID=630176
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=29&LettingCycleID=630175
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=29&LettingCycleID=630174
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=29&LettingCycleID=630173
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=29&LettingCycleID=630172
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=35&LettingCycleID=630119
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=35&LettingCycleID=630118
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=35&LettingCycleID=630117
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=35&LettingCycleID=630116
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=35&LettingCycleID=630115
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=35&LettingCycleID=630114
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=35&LettingCycleID=630113
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=35&LettingCycleID=630112
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=35&LettingCycleID=630111
# On page: /Data/ASPPages/1/56.aspx?CurrentPage=35&LettingCycleID=630110

# %% [markdown]
# ## Web Data Scraping: stage 5
#
# The block below is straightforward in that it does only one thing, writes the data frame to a CSV file on disk.

# %%
housing_df.to_csv('housing_information.csv',
                  index=False)
